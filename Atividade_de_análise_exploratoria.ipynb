# %% [markdown]
# **Sobre a base de dados**
#
# Os dados de rotatividade de clientes de telecomunicações contêm informações sobre uma empresa de telecomunicações fictícia que forneceu serviços de telefone residencial e Internet para 7.043 clientes na Califórnia.
#
# **Dicionário de dados**
#
#
# * CustomerId: Customer Id
# * Gender: Gender
# * SeniorCitizen: Whether the customer is elderly (1.0)
# * Partner: Whether the customer has a partner (Yes, No)
# * Dependents: Whether the customer has dependents (Yes, No) (child, mother, father...)
# * tenure: The number of months the customer stays in the company
# * PhoneService: Whether the customer has phone service (Yes, No)
# * MultipleLines: Whether the customer has more than one line (Yes, No, No phone service)
# * InternetService: Customer's internet service provider (DSL, Fiber optic, No)
# * OnlineSecurity: Whether the customer has online security (Yes, No, no Internet service)
# * OnlineBackup: Whether the customer has an online backup (Yes, No, no Internet service)
# * DeviceProtection: Whether the customer has device protection (Yes, No, no Internet service)
# * TechSupport: Whether the customer receives technical support (Yes, No, no Internet service)
# * StreamingTV: Whether the customer has broadcast TV (Yes, No, no Internet service)
# * StreamingMovies: Whether the customer is streaming movies (Yes, No, no Internet service)
# * Contract: Customer's contract period (Month to month, One year, Two years)
# * PaperlessBilling: Whether the customer has a paperless invoice (Yes, No)
# * PaymentMethod: Customer's payment method (Electronic check, Postal check, Bank transfer, Credit card)
# * MonthlyCharges: Amount collected from the customer monthly
# * TotalCharges: Total amount collected from the customer
# * Churn: Yes = the customer left the company this Month. No = the customer remained with the company.

# %% [markdown]
# #### **Faça uma análise exploratoria da base de dados. Utilize das técnicas que aprendeu nas aulas para analisar como os dados estão distribuidos e quais as relações entre eles. Elabore perguntas que podem ser respondidas através dessa análise e justifique suas respostas com base nos dados.**
#
# *Nesta atividade será avaliada sua habilidade de aplicar comandos do pandas para extrair conhecimento dos dados, assim como sua resposta para cada questão levantada.*
#
#
#
#
# Exemplo de perguntas que podem ser respondidas:
#
#
#
# * Qual a porcentagem de clientes que cancelaram o serviço (churn)?
# * Qual a distribuição dos clientes por gênero, idade (SeniorCitizen), estado civil (Partner), dependentes (Dependents)?
# * Qual a média, mediana e desvio padrão da permanência na empresa (tenure) e dos valores mensais (MonthlyCharges) e totais (TotalCharges)?
# * Clientes do gênero masculino ou feminino têm maior propensão ao churn?
# * Clientes idosos (SeniorCitizen) tendem a cancelar o serviço com mais frequência?
# * Clientes casados (Partner) ou com dependentes (Dependents) apresentam taxas de churn diferentes?
# * Existe alguma relação entre o número de linhas telefônicas (MultipleLines) e o churn?
# * Clientes com internet de fibra óptica (Fiber optic) cancelam menos que os demais?
# * Serviços adicionais como segurança online (OnlineSecurity), backup online (OnlineBackup) e proteção de dispositivos (DeviceProtection) afetam a taxa de churn?
# * O tipo de contrato (Month to month, One year, Two years) influencia na permanência do cliente?
# * Qual a proporção de clientes que possui telefone fixo (PhoneService)?
# * Quantos clientes possuem internet (InternetService) e qual a distribuição entre os tipos (DSL, Fiber optic)?
# * Qual a porcentagem de clientes que utiliza serviços de streaming (StreamingTV, StreamingMovies)?
# * Existe alguma relação entre o valor mensal faturado (MonthlyCharges) e o churn?
# * O valor total faturado (TotalCharges) está associado a propensão do cliente cancelar o serviço?
# * Qual o método de pagamento mais utilizado pelos clientes (Electronic check, Postal check, Bank transfer, Credit card)?
# * Existe alguma relação entre o método de pagamento e o churn?
# * Clientes com fatura eletrônica (PaperlessBilling) tendem a cancelar menos?

# %%
import pandas as pd

# %%
path = 'https://raw.githubusercontent.com/profEraylson/datasets/main/churn_telecom.csv'

df = pd.read_csv(path)

# %% [markdown]
# # De início, vamos analisar e verificar nossos dados para podermos entender e começar a análise.

# %%
df # Visualizar o DataFrame
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head(5) # primeiras 5 linhas da tabela
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail(5) # utimas 5 linhas
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.isna().sum()# Retorna a soma de todos os True (no caso, nos informa a quantidade de valores nulos em cada coluna).
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.info()# Informações do tipo dos dados.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape # formato do dataframe em linhas e colunas
# Out:
# (7043, 21)

# %%
df.duplicated().any()# ira nos retornar True se pelo menos uma linha for duplicada, caso contraria, nos retorna False
# Out:
# False

# %%
df.transpose().duplicated().sum() #indica que não há colunas duplicadas
# Out:
# 0

# %%
df.index# Irá retornar onde o índex inicia, onde termina e o número de passos (passos: se ele vai de um a um na tabela, por exemplo)
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
df.dtypes#Mim mostra todos os tipos de dados contidos em dataframe
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.drop('customerID', axis=1, inplace=True)#apagando a coluna id pois não é util para a analise

# %%
df#verificando
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# # Ao analisar o DataFramer podemos ver que precisamos Converte 'TotalCharges' para float, o 'SeniorCitizen' precisa ser rotulada para 'No' e 'Yes' e por utimo 'tenure', 'MonthlyCharges' e 'TotalCharges' são os únicas variáveis numéricas. ao final iremos transfoma os dados tipo 'object' para 'categry'

# %%
df['TotalCharges'] = df['TotalCharges'].replace(' ', '0')# Substituir valores vazios por zero
df['TotalCharges'] = df['TotalCharges'].astype(float)# Convertendo a coluna 'TotalCharges' para float

# %%
df.dtypes#verifcamos
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].replace({1: 'Yes', 0: 'No'})

# %%
df#verifcamos
# Out:
#       gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female            No     Yes         No       1           No
# 1       Male            No      No         No      34          Yes
# 2       Male            No      No         No       2          Yes
# 3       Male            No      No         No      45           No
# 4     Female            No      No         No       2          Yes
# ...      ...           ...     ...        ...     ...          ...
# 7038    Male            No     Yes        Yes      24          Yes
# 7039  Female            No     Yes        Yes      72          Yes
# 7040  Female            No     Yes        Yes      11           No
# 7041    Male           Yes     Yes         No       4          Yes
# 7042    Male            No      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].astype("object")  # Convertendo a coluna SeniorCitizen para object

# %%
df.dtypes #verifcamos
# Out:
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
var_categoricas = list(df.select_dtypes("object").columns)#seleciona todas as colunas que di tipo objeto
df[var_categoricas] = df[var_categoricas].astype('category')# agora transformo todas ela em variaveis do tipo category

# %%
df.dtypes#verifcamos
# Out:
# gender              category
# SeniorCitizen       category
# Partner             category
# Dependents          category
# tenure                 int64
# PhoneService        category
# MultipleLines       category
# InternetService     category
# OnlineSecurity      category
# OnlineBackup        category
# DeviceProtection    category
# TechSupport         category
# StreamingTV         category
# StreamingMovies     category
# Contract            category
# PaperlessBilling    category
# PaymentMethod       category
# MonthlyCharges       float64
# TotalCharges         float64
# Churn               category
# dtype: object

# %% [markdown]
# ## Agora, feitas as adequações com os dados, iremos dar início às análises e responder às perguntas.

# %% [markdown]
# # 1°- Qual a porcentagem de clientes que cancelaram o serviço (churn)?

# %%
df['Churn'].value_counts(normalize=True).mul(100).round(2)#agora mostro em percentual mutiplicando por 100 e definido 2 casas decimais
#Yes = o cliente saiu da empresa este mês.   No = o cliente permaneceu na empresa.
# Out:
# No     73.46
# Yes    26.54
# Name: Churn, dtype: float64

# %% [markdown]
# R=26,54% dos clientes cancelaram o cerviço

# %% [markdown]
# # 2°- Qual a distribuição dos clientes por gênero, idade (SeniorCitizen), estado civil (Partner), dependentes (Dependents)?

# %%
import seaborn as sns   #biblioteca usada para plotar graficos

# %%
numero_de_categ = len(df['gender'].unique()) # ira retorna a quantidade de categoras  para poder faser a destribuição
sns.displot(data = df, x = 'gender',bins = numero_de_categ)#chamando grafico de destribuição

# %%
numero_de_categ = len(df['SeniorCitizen'].unique()) # ira retorna a quantidade de categoras  para poder faser a destribuição
labels = ['-65 anos', '+=65 anos']
sns.displot(data = df, x = 'SeniorCitizen',bins = numero_de_categ).set(xticklabels=labels)#chamando grafico de destribuição
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set(**kwargs)

# %%
numero_de_categ = len(df['Partner'].unique()) # ira retorna a quantidade de categoras  para poder faser a destribuição
labels = ['Casado', 'Solteiro']
sns.displot(data = df, x = 'Partner',bins = numero_de_categ).set(xticklabels=labels)#chamando grafico de destribuição
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set(**kwargs)

# %%
numero_de_categ = len(df['Dependents'].unique()) # ira retorna a quantidade de categoras  para poder faser a destribuição
labels = ['Com dependente', 'Sem dependente']
sns.displot(data = df, x = 'Dependents',bins = numero_de_categ).set(xticklabels=labels)#chamando grafico de destribuição
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:44: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set(**kwargs)

# %% [markdown]
# # 3°- Qual a média, mediana e desvio padrão da permanência na empresa (tenure) e dos valores mensais (MonthlyCharges) e totais (TotalCharges)?

# %%
df_numbers = df.select_dtypes("number")#seleciona todas as colunas que são do tipo numerico

# %%
df_numbers.mean()#média
# Out:
# tenure              32.371149
# MonthlyCharges      64.761692
# TotalCharges      2279.734304
# dtype: float64

# %%
df_numbers.median() # moda
# Out:
# tenure              29.00
# MonthlyCharges      70.35
# TotalCharges      1394.55
# dtype: float64

# %%
df_numbers.std()# desvio padrão
# Out:
# tenure              24.559481
# MonthlyCharges      30.090047
# TotalCharges      2266.794470
# dtype: float64

# %% [markdown]
# # 4°- Clientes do gênero masculino ou feminino têm maior propensão ao churn?

# %%
df.groupby('gender')['Churn'].value_counts(normalize=True).mul(100).round(2)#groupby faz o agrupamento e passa em relação a que se que calcular
# Out:
# gender  Churn
# Female  No       73.08
#         Yes      26.92
# Male    No       73.84
#         Yes      26.16
# Name: Churn, dtype: float64

# %% [markdown]
# R = Com isso, vemos que o gênero feminino que irá deixar a empresa este trimestre é de aproximadamente 0,76% maior que a de homens, como pode ser visto no gráfico a baixo.

# %%
sns.countplot(data=df, x='gender', hue='Churn')#plota a correlação categorica de churn por gênero
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# # 5°- Clientes idosos (SeniorCitizen) tendem a cancelar o serviço com mais frequência?

# %%
df.groupby('SeniorCitizen')['Churn'].count()#conferindo o numero de idosos
# Out:
# SeniorCitizen
# No     5901
# Yes    1142
# Name: Churn, dtype: int64

# %%
df.groupby('SeniorCitizen')['Churn'].value_counts(normalize=True).mul(100).round(2)#groupby faz o agrupamento e passa em relação a que se que calcular
# Out:
# SeniorCitizen  Churn
# No             No       76.39
#                Yes      23.61
# Yes            No       58.32
#                Yes      41.68
# Name: Churn, dtype: float64

# %%
sns.countplot(df, x="SeniorCitizen",hue='Churn')#plota a correlação categorica
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# R = Sim, clientes idosos tendem a cancelar 18% a mais que clientes abaixo dos 65 anos

# %% [markdown]
# # 6°- Clientes casados (Partner) ou com dependentes (Dependents) apresentam taxas de churn diferentes?

# %%
dependentes = df.groupby('Partner')['Churn'].value_counts(normalize=True).mul(100).round(2)#groupby faz o agrupamento e passa em relação a que se que calcular
dependentes
# Out:
# Partner  Churn
# No       No       67.04
#          Yes      32.96
# Yes      No       80.34
#          Yes      19.66
# Name: Churn, dtype: float64

# %%
dependentes = df.groupby('Dependents')['Churn'].value_counts(normalize=True).mul(100).round(2)#groupby faz o agrupamento e passa em relação a que se que calcular
dependentes
# Out:
# Dependents  Churn
# No          No       68.72
#             Yes      31.28
# Yes         No       84.55
#             Yes      15.45
# Name: Churn, dtype: float64

# %%
dependentespd = df.groupby(['Partner', 'Dependents'])['Churn'].value_counts(normalize=True).mul(100).round(2).unstack()#groupby faz o agrupamento e passa em relação a que se que calcular
dependentespd
# Out:
# Churn                  No    Yes
# Partner Dependents
# No      No          65.76  34.24
#         Yes         78.67  21.33
# Yes     No          74.59  25.41
#         Yes         85.76  14.24

# %%
sns.barplot(x='Dependents', y='Yes', hue='Partner', data=dependentespd)# Visualizar os resultados usando um gráfico de barras
# Out:
# <Axes: xlabel='Dependents', ylabel='Yes'>

# %% [markdown]
# R= podemos observar que clientes com dependentes (Dependents = Yes) tendem a apresentar uma taxa de churn menor em comparação com clientes que não têm dependentes (Dependents = No), independentemente de terem um parceiro (Partner). Além disso, clientes com ambos parceiro e dependentes (Partner = Yes, Dependents = Yes) têm a menor taxa de churn entre todas as categorias.

# %% [markdown]
# # 7°- Existe alguma relação entre o número de linhas telefônicas (MultipleLines) e o churn?

# %%
df['MultipleLines'].unique()
# Out:
# ['No phone service', 'No', 'Yes']
# Categories (3, object): ['No', 'No phone service', 'Yes']

# %%
df_c = df.select_dtypes("category")
df_c
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
# ...

# %%
pd.crosstab(df_c['Churn'],df_c['MultipleLines'], normalize='index')
# Out:
# MultipleLines        No  No phone service       Yes
# Churn
# No             0.491109          0.098956  0.409934
# Yes            0.454254          0.090958  0.454789

# %% [markdown]
# R = Não há uma grande diferença na taxa de churn entre os clientes que possuem mais de uma linha telefônica e aqueles que não possuem. No entanto, os clientes que não possuem serviço de telefone apresentam a menor taxa de churn.

# %% [markdown]
# # 8°- Clientes com internet de fibra óptica (Fiber optic) cancelam menos que os demais?

# %%
cancelam = df.groupby('InternetService')['Churn'].value_counts(normalize=True).unstack()
cancelam
# Out:
# Churn                  No       Yes
# InternetService
# DSL              0.810409  0.189591
# Fiber optic      0.581072  0.418928
# No               0.925950  0.074050

# %%
sns.barplot(data=cancelam, x=cancelam.index, y='Yes')
# Out:
# <Axes: xlabel='InternetService', ylabel='Yes'>

# %% [markdown]
# R= Não, pelo contrario, os clientes com internet de fibra óptica apresentam uma taxa de churn significativamente mais alta em comparação com os clientes com serviço DSL e aqueles que não possuem serviço de internet. Logo, isso sugere que há uma relação entre o tipo de serviço de internet e a probabilidade de churn, sendo que os clientes com serviço de fibra óptica tendem a cancelar mais frequentemente.

# %% [markdown]
# # 9°- Serviços adicionais como segurança online (OnlineSecurity), backup online (OnlineBackup) e proteção de dispositivos (DeviceProtection) afetam a taxa de churn?

# %%
churn_global = df['Churn'].value_counts(normalize=True) * 100# Calcular a taxa de churn global
print("Taxa de churn global:")
print(churn_global)
print()

servicos = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection']#Explorar a relação entre os serviços adicionais e a taxa de churn
churn_por_servicos = df.groupby(servicos)['Churn'].value_counts(normalize=True).unstack()
churn_por_servicos
# Out:
# Taxa de churn global:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64
# Churn                                                              No  \
# OnlineSecurity      OnlineBackup        DeviceProtection
# No                  No                  No                   0.474486
#                                         Yes                  0.615160
#                     Yes                 No                   0.651917
#                                         Yes                  0.731200
# No internet service No internet service No internet service  0.925950
# Yes                 No                  No                   0.751579
#                                         Yes                  0.861244
#                     Yes                 No                   0.852194
#                                         Yes                  0.920635
#
# Churn                                                             Yes
# ...

# %%
import matplotlib.pyplot as plt

churn_por_servicos.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='OnlineSecurity,OnlineBackup,DeviceProtection'>

# %% [markdown]
# R= Emfluencia pois quem não tem nehum cerviço de proteção tem chace de 52%  deixA a empresa este trimestre emquanto quem tem todos esse numero cai para 7,9%

# %% [markdown]
# # 10°- O tipo de contrato (Month to month, One year, Two years) influencia na permanência do cliente?

# %%
influencia = df.groupby('Contract')['Churn'].value_counts(normalize=True).mul(100).unstack()#groupby faz o agrupamento e passa em relação a que se que calcular
influencia
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %%
sns.barplot(data=influencia, x=influencia.index, y='Yes')
# Out:
# <Axes: xlabel='Contract', ylabel='Yes'>

# %% [markdown]
# R = imfuencia pois, 42,7% dos clientes que possui contratos Month-to-month	deixo a empresa, enquanto que para One year é 11,2% e para Two year é 2,8%

# %% [markdown]
# # **11°**-Qual a proporção de clientes que possui telefone fixo (PhoneService)?

# %%
df['PhoneService'].value_counts(normalize=True).mul(100).round(2)#agora mostro em percentual mutiplicando por 100 e definido 2 casas decimais
# Out:
# Yes    90.32
# No      9.68
# Name: PhoneService, dtype: float64

# %% [markdown]
# R= A proporção de clientes com telefone fixo é de 90.32%. E 9.68% Não possuem telefone fixo.

# %% [markdown]
# # 12°- Quantos clientes possuem internet (InternetService) e qual a distribuição entre os tipos (DSL, Fiber optic)?

# %%
quantidade = df['InternetService'].value_counts(normalize=True).mul(100).round(2)#agora mostro em percentual mutiplicando por 100 e definido 2 casas decimais
print(f'possuem internet: {100 - quantidade["No"]:.2f}')#calcula o percentual de quem tem internet
quantidade
# Out:
# possuem internet: 78.33
# Fiber optic    43.96
# DSL            34.37
# No             21.67
# Name: InternetService, dtype: float64

# %%
sns.displot(data = df, x = 'InternetService',bins = 4, stat = 'probability')# Plotar o gráfico

# %% [markdown]
# R= 78,33% Possuen dos clientes possuem internet, dos quis 43,96 sõa fibra óptica (fiber optic) e 34,37 São DSL. Os outros 21,67 não possuem internet da impresa.

# %% [markdown]
# # 13°- Qual a porcentagem de clientes que utiliza serviços de streaming (StreamingTV, StreamingMovies)?

# %%
streaming = df[(df['StreamingTV'] == 'Yes') & (df['StreamingMovies'] == 'Yes')]# Filtrar os clientes

streaming =len(streaming) / len(df) * 100# Calcular a porcentagem de clientes

print(f"A porcentagem de clientes que utiliza serviços de streaming é de {streaming:.2f}%.")
# Out:
# A porcentagem de clientes que utiliza serviços de streaming é de 27.55%.

# %% [markdown]
# # 14°- Existe alguma relação entre o valor mensal faturado (MonthlyCharges) e o churn?

# %%
sns.kdeplot(data=df, x='MonthlyCharges', hue='Churn', fill=True, common_norm=False)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Density'>

# %% [markdown]
# R= Podemos observar que, em geral, as taxas de churn parecem variar de forma inconsistente com o aumento dos valores de cobrança mensal. Ela oscilam sem seguir um padrão claro de aumento ou diminuição à medida que o valor mensal aumenta.

# %% [markdown]
# # 15°- O valor total faturado (TotalCharges) está associado a propensão do cliente cancelar o serviço?

# %%
sns.kdeplot(data=df, x='TotalCharges', hue='Churn', fill=True, common_norm=False)
# Out:
# <Axes: xlabel='TotalCharges', ylabel='Density'>

# %% [markdown]
# R= Podemos observar que, em geral, as taxas de churn parecem variar de forma concistente com o aumento dos valores de cobrança trimestral. Ela oscilam seguindo um certo padrão e aparentimente os cancelamentos dimnuen a medida que o valor de total (TotalCharges) almenta.

# %% [markdown]
# # 16°- Qual o método de pagamento mais utilizado pelos clientes (Electronic check, Postal check, Bank transfer, Credit card)?

# %%
df['PaymentMethod'].value_counts(normalize=True).mul(100).round(2)#agora mostro em percentual mutiplicando por 100 e definido 2 casas decimais
# Out:
# Electronic check             33.58
# Mailed check                 22.89
# Bank transfer (automatic)    21.92
# Credit card (automatic)      21.61
# Name: PaymentMethod, dtype: float64

# %% [markdown]
# R= o método de pagamento mais utilizado pelos clientes o Electronic check com 33.58% dos clientes utilizando essa forma de pagamento.

# %% [markdown]
# # 17°- Existe alguma relação entre o método de pagamento e o churn?

# %%
relacao = df.groupby('PaymentMethod')['Churn'].value_counts(normalize=True).unstack()
relacao
# Out:
# Churn                            No       Yes
# PaymentMethod
# Bank transfer (automatic)  0.832902  0.167098
# Credit card (automatic)    0.847569  0.152431
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067

# %%
sns.barplot(data=relacao, x=relacao.index, y='Yes')# Criar o gráfico de barras

plt.xticks(rotation=45, ha='right')# Rotacionar os rótulos do eixo x para facilitar a leitura
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Bank transfer (automatic)'),
#   Text(1, 0, 'Credit card (automatic)'),
#   Text(2, 0, 'Electronic check'),
#   Text(3, 0, 'Mailed check')])

# %% [markdown]
# R= como podemos ver existe uma relação entre o método de pagamento e as assinaturas canceladas, pois 45% dos clientes que cancelam é pelo metedo de (Electronic check).

# %% [markdown]
# # 18°- Clientes com fatura eletrônica (PaperlessBilling) tendem a cancelar menos?

# %% [markdown]
# R= para responder essa questão iremos utilizar a resposta anterio, onde podemps ver que na verdade os clientes com fatura eletrônica (PaperlessBilling) tendem a cancelar mais
